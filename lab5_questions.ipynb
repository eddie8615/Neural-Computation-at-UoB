# %% [markdown]
# # Lab 5: High-dimensional Gradient Descent
#
# In this exercise, you will learn the following
#
# * how to define a probability density function
# * how to fit a Gaussian model using maximum likelihood estimation
# * how to define a loss function via log likelihood
# * how to produce scatter and line plots using Matplotlib
# * how to train a Gaussian model using high-dimensional gradient descent/ascent
# * how to use pytorch for automated gradient descent/ascent
#
# To solve the exercise, you need to fill in some code below. Suggested solutions will be posted on Canvas later.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Define probability density function and visualise data
#
# First, you need to load the dataset from the last tutorial, which contains 100000 independent observations sampled from a normal distribution

# %%
url = "http://www.cs.bham.ac.uk/~duanj/log/Gaussian_Distrbution/Gaussian_100000.csv"
data = np.genfromtxt(url, delimiter=",", skip_header=0, usecols=(0))

# %% [markdown]
# As we know our `data` above was sampled from a normal distribution, if we plot its histogram we will be able to see such a distribution visually.

# %%
plt.hist(data, 100, density=True)
plt.ylabel('No of times')
# Out:
# Text(0, 0.5, 'No of times')

# %% [markdown]
# On top of the `data` and its histogram, we want to fit a Gaussian-like curve. To do so, we will need to define the probability density function of a Gaussian distribution. Below please write such probability density function with `mean` and `std` being model parameters and `x` representing the observations from the distribution

# %%
def prob_density_func(x, mean, std):
    return (1/(np.sqrt(2 * np.pi * std**2))) * np.exp(-0.5 * ((x - mean)**2) / (std**2))

# %% [markdown]
# Let's try to fit a curve using `prob_density_func` you defined above.

# %%
data_regrid = np.linspace(np.min(data),np.max(data), data.shape[0])
mean, std = 5, 6
pdf = prob_density_func(data_regrid, mean, std)

plt.hist(data, 100, density=True)
plt.ylabel('No of times')
plt.plot(data_regrid, pdf, 'k--')
plt.show()

# %% [markdown]
# Ops! You can see the curve is not fitting the data very well. Please write down in the following your code which gives the correct fitting. Hint: using the maximum likelihood estimation results from the last lab tutorial.

# %%
mean = np.mean(data)
std = np.std(data)
print(mean)
pdf = prob_density_func(data_regrid, mean, std)

plt.hist(data, 100, density=True)
plt.ylabel('No of times')
plt.plot(data_regrid, pdf, 'k--')
plt.show()
# Out:
# 2.02020308037172

# %% [markdown]
# ## Defining a loss function
#
# As shown above, you can derive the explicit solutions with respect to the model parameters `mean` and `std`. However, this is not always the case for most deep learning models. Another way to compute a curve that can fit the data very well is to use gradient descent/ascent. To do so, we need two functions that defines the loss function and its gradients.
#
# From the last tutorial, we know that for a normal distribution the loss function is essentially the log likelihood of a joint probability density function. Below please write down your code to define such loss function

# %%
def log_likelihood(data, mean, std):    
    size = len(data)
    return (-size / 2)* np.log(2*np.pi*std**2) - np.sum(((data - mean)**2) / (2*std**2))

# %% [markdown]
# To apply gradient descent/ascent to iteratively optimise the model parameters `mean` and `std`, we need to calculate the derivatives (ie. gradients) with respect to the parameters. Below please write down your code to implement `gradient`.

# %%
def gradient(data, mean, std):
    return [np.gradient(log_likelihood(data,mean,std), np.diff(mean)), np.gradient(log_likelihood(data,mean,std), np.diff(std))]

# %% [markdown]
# We now want to visualise the landscape of the loss function. The idea is to create two 2D meshgrids, which respectively represent discrete values of mean and standard deviation. These values are then passed to the `log_likelihood` to compute the loss on a 2D meshgrid. Please write down your code in the place indicated by #

# %%
mean_1D_grid = np.arange(1.0, 4.1, 0.1)
std_1D_grid = np.arange(3.0, 6.1, 0.1)

mean_2D_grid, std_2D_grid = np.meshgrid(mean_1D_grid, std_1D_grid)

row = mean_1D_grid.shape[0]
col = std_1D_grid.shape[0]

loss_2D_grid = np.zeros([row, col])

# write down your code here. Hint: you should use nested loops
for i in range(row):
    for j in range(col):
        loss_2D_grid[i][j] = log_likelihood(data, mean_1D_grid[i], std_1D_grid[j])

print('done the loop')

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(10)
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(mean_2D_grid, std_2D_grid, loss_2D_grid)

ax.set_xlabel('mean values')
ax.set_ylabel('standard deviation')
ax.set_zlabel('log likelihood')
ax.view_init(25, -50)

fig.canvas.draw()
# Out:
# done the loop
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## High-dimensional gradient descent/ascent
#
# In this final section, we are going to use the gradient descend/ascent method to find the model parameters `mean` and `std`. In gradient descent/ascent, we usually work with an update scheme for the parameters using a small learning rate $\epsilon$. The update rule can be defined as follows
#
# $$ [mean, std] \leftarrow [mean, std] - \epsilon \times  gradient$$
#
# Here we use a learning rate $\epsilon = 0.00002$ and initial parameters $mean=4$ and $std=6$. A for-loop will iteratively update the value of parameters (see the body of the for-loop). After each update, the new value of parameters will be plotted, and over time, it shows clearly how the parameters is updated until converging to the global optimum.
#
# Complete the code below so that the parameters `mean` and `std` is updated via gradient descent/ascent. Write down your code in the place indicated by #

# %%
# %matplotlib notebook

import time

# set up the canvas
fig = plt.figure(figsize=(10,5))
ax1 = plt.subplot(121)
ax2 = plt.subplot(122, projection='3d')

plt.ion()
fig.show()
fig.canvas.draw()

# set learning rate
epsilon = 0.00002

# Initial mean and std
mean_, std_ = 4, 6
parameters = np.array([mean_, std_])

    
for i in range(1, 50):   
    
    # write down your code here.
           
    ax1.clear()
    ax1.hist(data, 100, density=True)
    ax1.set_ylabel('No of times')
    data_regrid = np.linspace(np.min(data),np.max(data), data.shape[0])
    pdf = prob_density_func(data_regrid, parameters[0], parameters[1])
    ax1.plot(data_regrid, pdf, 'k--')
    
    ax2.clear()
    ax2.scatter3D(parameters[0], parameters[1], log_likelihood(data, parameters[0], parameters[1]), s=500, color="r")
    ax2.view_init(25, -50)
    ax2.plot_surface(mean_2D_grid, std_2D_grid, loss_2D_grid)
    ax2.set_xlabel('mean values')
    ax2.set_ylabel('standard deviation')
    ax2.set_zlabel('log likelihood')
        
    fig.canvas.draw()
    time.sleep(0.01)
    
    
print('gradient ascent mean {}'.format(parameters[0]))
print('gradient ascent std {}'.format(parameters[1]))
    
print('ground truth mean {}'.format(np.mean(data)))
print('ground truth std {}'.format(np.std(data)))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# [[], []]
# gradient ascent mean 4
# gradient ascent std 6
# ground truth mean 2.02020308037172
# ground truth std 3.994776297943574

# %% [markdown]
# ## Introduction of pytorch
#
# So far, we have walked you through a 1D gradient descent case (ie. linear regression) and a high-dimensional 2D gradient descent case (ie. Gaussian curve fitting). It is now the time to introduce you [`pytorch`](https://pytorch.org/features/), which allows implementations of modern, powerful deep learning neural networks in a very simple yet efficient way.
#
# The question naturally raises as to what pytorch is? The answers to this are summarised as follows
#
# `Pytorch` is a python-based scientific computing package targeted at two sets of audiences:
#
# * A replacement for NumPy to use the power of GPUs
# * A deep learning research platform that provides maximum flexibility and speed
#
# As a start point, we ask you to quickly go through the tutorial from [here](https://pytorch.org/tutorials/beginner/blitz/tensor_tutorial.html#sphx-glr-beginner-blitz-tensor-tutorial-py) about some basic usage of pytorch tensors.
#
# In addition to the use of GPUs, another very important feature about `pytorch` is *Automatic Differentiation*, which allows to numerically evaluate the derivative of a function/model specified by a computer program without any manual gradient calculations. That is to say we do not need something like `def gradient(data, mean, std)` defined above anymore. For a more detailed introduction of *Automatic Differentiation* in pytorch, please read [here](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html#sphx-glr-beginner-blitz-autograd-tutorial-py).
#
# In what follows, we will leverage the power of *Automatic Differentiation*. We will cover how to use GPUs using pytorch in later tutorials. As pytorch has been installed for our module, we can directly use it.

# %%
# %reset
import torch # pytorch
import torch.nn as nn
import torch.optim as optim
import numpy as np
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# Let's first import necessary pytorch libraries, which are `torch`, `torch.nn` and `torch optim`. These packages are explained as follows:
#
# * `torch`: a general purpose array library similar to Numpy that can do computations on GPUs when the tensor type is cast to (torch.cuda.TensorFloat)
#
# * `torch.nn`: a neural net library with common layers and cost functions
# * `torch.optim`: an optimisation package with common optimisation algorithms like SGD, Adam, etc
#
# The following describes a straightforward framework that reflects the coding structure of almost all other deep learning methods. You should get yourself really familiar with the framework. Its main building blocks (their orders may change) includes:
#
# * define a model
# * choose a optimiser
# * define a loss function
# * load data
# * train model parameters iteratively to minimise the loss
#
# Let's walk through each of steps above individually.

# %%
# define a model class
class prob_density_func(nn.Module):
    def __init__(self, mean=1, std=1):
        super(prob_density_func, self).__init__()
       
        self.mean = torch.nn.Parameter(torch.Tensor([mean]))  
        self.std = torch.nn.Parameter(torch.Tensor([std]))
    
    def forward(self, x):
        return (1/(torch.sqrt(2*np.pi*self.std**2)))*(torch.exp(-0.5*(x - self.mean)**2/self.std**2))
    
    def extra_repr(self):
        return self.mean.item(), self.std.item()

# %% [markdown]
# First, we define a model class where one can see three parts: `__init__(self, mean=1, std=1)`, `forward(self, x)` and `extra_repr(self)`, which have the following meaning
#
# `__init__(self, mean=1, std=1)`: initialise all model parameters. Here we initialise `mean=1` and `std=1`. Of note, these two parameters can be overwritten later if needed.
#
# `forward(self, x)`: defines the computational model. Here our model is a probability density function (pdf) of a normal distribution. Please write down your code in this function. Note that you should use functions from `torch` instead of `numpy`, such as `torch.sqrt()` and `torch.exp()`. Also note that you should use `self.mean` and `self.std` for the pdf.
#
# `extra_repr`: prints the mean value and std value if invoked.
#
# We also note that by using the `self` keyword we can access the attributes and methods within the class.

# %%
# declare the model
mean_, std_ = 4, 6
model = prob_density_func(mean_, std_)

# %% [markdown]
# Above we define the model with a new mean value and a new std value.

# %%
# define an optimiser
epsilon = 0.00002
optimizer = optim.SGD(model.parameters(), lr=epsilon)

# %% [markdown]
# Above we choose a optimisation algorithm (ie. Stochastic Gradient Descent) to minimise the model defined

# %%
# define the loss function
def loss_fuc(pdf):
    return -torch.sum(torch.log(pdf))

# %% [markdown]
# Above we define the loss function which is negative log likelihood of the joint probability density function of the distribution. Please write down your code above to implement the loss. Note that you should use functions from `torch` instead of `numpy`, such as `torch.log()` and `torch.sum()`.

# %%
# load input data
url = "http://www.cs.bham.ac.uk/~duanj/log/Gaussian_Distrbution/Gaussian_100000.csv"
data = np.genfromtxt(url, delimiter=",", skip_header=0, usecols=(0))
data = torch.from_numpy(data.astype(np.float32))

# %% [markdown]
# Above we load the dataset and then convert it to `torch` format such that *Automatic Differentiation* applies.
#
# In the following, we then start to train the model such that as iteration proceeds the optimal model parameters are searched via SGD. At the beginning, we need to set the gradients to zero (hence `optimizer.zero_grad()`) before starting to do backpropagation because PyTorch accumulates the gradients on subsequent backward passes. The results after feeding data to `model()` will be passed to `loss_fuc()` to compute the loss. Afterwards, `loss.backward()` computes `dloss/dx` for every model parameter `x`. In our application `x` is a vector of `mean` and `std`. These are accumulated into `x.grad` for every parameter `x`. In pseudo-code it reads:
#
# `x.grad += dloss/dx`
#
# Finally, `optimizer.step()` updates the value of `x` using the gradient `x.grad`. For example, the SGD optimizer performs:
#
# `x += -lr * x.grad`
#
# which is the same as what you have been shown in the previous section of manual gradient descent.

# %%
# find the optimal values of mean and std using Automatic Differentiation and backpropagation
for i in range(1, 500):
    print ('iteration proceeds {}'.format(i))
   
    optimizer.zero_grad() 
    
    pdf = model(data)
    loss_value = loss_fuc(pdf)
    
    loss_value.backward()
    optimizer.step()
    
mean, std = model.extra_repr()
print('gradient descent mean via torch {}'.format(mean))
print('gradient descent std via torch {}'.format(std))

data = np.genfromtxt(url, delimiter=",", skip_header=0, usecols=(0))
print('ground truth mean via maximum likelihood {}'.format(np.mean(data)))
print('ground truth std via maximum likelihood {}'.format(np.std(data)))
# Out:
# iteration proceeds 1
# iteration proceeds 2
# iteration proceeds 3
# iteration proceeds 4
# iteration proceeds 5
# iteration proceeds 6
# iteration proceeds 7
# iteration proceeds 8
# iteration proceeds 9
# iteration proceeds 10
# iteration proceeds 11
# iteration proceeds 12
# iteration proceeds 13
# iteration proceeds 14
# iteration proceeds 15
# iteration proceeds 16
# iteration proceeds 17
# iteration proceeds 18
# iteration proceeds 19
# iteration proceeds 20
# iteration proceeds 21
# iteration proceeds 22
# iteration proceeds 23
# iteration proceeds 24
# iteration proceeds 25
# iteration proceeds 26
# iteration proceeds 27
# iteration proceeds 28
# iteration proceeds 29
# iteration proceeds 30
# iteration proceeds 31
# iteration proceeds 32
# iteration proceeds 33
# iteration proceeds 34
# iteration proceeds 35
# iteration proceeds 36
# iteration proceeds 37
# iteration proceeds 38
# iteration proceeds 39
# iteration proceeds 40
# iteration proceeds 41
# iteration proceeds 42
# iteration proceeds 43
# iteration proceeds 44
# iteration proceeds 45
# iteration proceeds 46
# iteration proceeds 47
# iteration proceeds 48
# iteration proceeds 49
# iteration proceeds 50
# iteration proceeds 51
# iteration proceeds 52
# iteration proceeds 53
# iteration proceeds 54
# iteration proceeds 55
# iteration proceeds 56
# iteration proceeds 57
# iteration proceeds 58
# iteration proceeds 59
# iteration proceeds 60
# iteration proceeds 61
# iteration proceeds 62
# iteration proceeds 63
# iteration proceeds 64
# iteration proceeds 65
# iteration proceeds 66
# iteration proceeds 67
# iteration proceeds 68
# iteration proceeds 69
# iteration proceeds 70
# iteration proceeds 71
# iteration proceeds 72
# iteration proceeds 73
# iteration proceeds 74
# iteration proceeds 75
# iteration proceeds 76
# iteration proceeds 77
# iteration proceeds 78
# iteration proceeds 79
# iteration proceeds 80
# iteration proceeds 81
# iteration proceeds 82
# iteration proceeds 83
# iteration proceeds 84
# iteration proceeds 85
# iteration proceeds 86
# iteration proceeds 87
# iteration proceeds 88
# iteration proceeds 89
# iteration proceeds 90
# iteration proceeds 91
# iteration proceeds 92
# iteration proceeds 93
# iteration proceeds 94
# iteration proceeds 95
# iteration proceeds 96
# iteration proceeds 97
# iteration proceeds 98
# iteration proceeds 99
# iteration proceeds 100
# iteration proceeds 101
# iteration proceeds 102
# iteration proceeds 103
# iteration proceeds 104
# iteration proceeds 105
# iteration proceeds 106
# iteration proceeds 107
# iteration proceeds 108
# iteration proceeds 109
# iteration proceeds 110
# iteration proceeds 111
# iteration proceeds 112
# iteration proceeds 113
# iteration proceeds 114
# iteration proceeds 115
# iteration proceeds 116
# iteration proceeds 117
# iteration proceeds 118
# iteration proceeds 119
# iteration proceeds 120
# iteration proceeds 121
# iteration proceeds 122
# iteration proceeds 123
# iteration proceeds 124
# iteration proceeds 125
# iteration proceeds 126
# iteration proceeds 127
# iteration proceeds 128
# iteration proceeds 129
# iteration proceeds 130
# iteration proceeds 131
# iteration proceeds 132
# iteration proceeds 133
# iteration proceeds 134
# iteration proceeds 135
# iteration proceeds 136
# iteration proceeds 137
# iteration proceeds 138
# iteration proceeds 139
# iteration proceeds 140
# iteration proceeds 141
# iteration proceeds 142
# iteration proceeds 143
# iteration proceeds 144
# iteration proceeds 145
# iteration proceeds 146
# iteration proceeds 147
# iteration proceeds 148
# iteration proceeds 149
# iteration proceeds 150
# iteration proceeds 151
# iteration proceeds 152
# iteration proceeds 153
# iteration proceeds 154
# iteration proceeds 155
# iteration proceeds 156
# iteration proceeds 157
# iteration proceeds 158
# iteration proceeds 159
# iteration proceeds 160
# iteration proceeds 161
# iteration proceeds 162
# iteration proceeds 163
# iteration proceeds 164
# iteration proceeds 165
# iteration proceeds 166
# iteration proceeds 167
# iteration proceeds 168
# iteration proceeds 169
# iteration proceeds 170
# iteration proceeds 171
# iteration proceeds 172
# iteration proceeds 173
# iteration proceeds 174
# iteration proceeds 175
# iteration proceeds 176
# iteration proceeds 177
# iteration proceeds 178
# iteration proceeds 179
# iteration proceeds 180
# iteration proceeds 181
# iteration proceeds 182
# iteration proceeds 183
# iteration proceeds 184
# iteration proceeds 185
# iteration proceeds 186
# iteration proceeds 187
# iteration proceeds 188
# iteration proceeds 189
# iteration proceeds 190
# iteration proceeds 191
# iteration proceeds 192
# iteration proceeds 193
# iteration proceeds 194
# iteration proceeds 195
# iteration proceeds 196
# iteration proceeds 197
# iteration proceeds 198
# iteration proceeds 199
# iteration proceeds 200
# iteration proceeds 201
# iteration proceeds 202
# iteration proceeds 203
# iteration proceeds 204
# iteration proceeds 205
# iteration proceeds 206
# iteration proceeds 207
# iteration proceeds 208
# iteration proceeds 209
# iteration proceeds 210
# iteration proceeds 211
# iteration proceeds 212
# iteration proceeds 213
# iteration proceeds 214
# iteration proceeds 215
# iteration proceeds 216
# iteration proceeds 217
# iteration proceeds 218
# iteration proceeds 219
# iteration proceeds 220
# iteration proceeds 221
# iteration proceeds 222
# iteration proceeds 223
# iteration proceeds 224
# iteration proceeds 225
# iteration proceeds 226
# iteration proceeds 227
# iteration proceeds 228
# iteration proceeds 229
# iteration proceeds 230
# iteration proceeds 231
# iteration proceeds 232
# iteration proceeds 233
# iteration proceeds 234
# iteration proceeds 235
# iteration proceeds 236
# iteration proceeds 237
# iteration proceeds 238
# iteration proceeds 239
# iteration proceeds 240
# iteration proceeds 241
# iteration proceeds 242
# iteration proceeds 243
# iteration proceeds 244
# iteration proceeds 245
# iteration proceeds 246
# iteration proceeds 247
# iteration proceeds 248
# iteration proceeds 249
# iteration proceeds 250
# iteration proceeds 251
# iteration proceeds 252
# iteration proceeds 253
# iteration proceeds 254
# iteration proceeds 255
# iteration proceeds 256
# iteration proceeds 257
# iteration proceeds 258
# iteration proceeds 259
# iteration proceeds 260
# iteration proceeds 261
# iteration proceeds 262
# iteration proceeds 263
# iteration proceeds 264
# iteration proceeds 265
# iteration proceeds 266
# iteration proceeds 267
# iteration proceeds 268
# iteration proceeds 269
# iteration proceeds 270
# iteration proceeds 271
# iteration proceeds 272
# iteration proceeds 273
# iteration proceeds 274
# iteration proceeds 275
# iteration proceeds 276
# iteration proceeds 277
# iteration proceeds 278
# iteration proceeds 279
# iteration proceeds 280
# iteration proceeds 281
# iteration proceeds 282
# iteration proceeds 283
# iteration proceeds 284
# iteration proceeds 285
# iteration proceeds 286
# iteration proceeds 287
# iteration proceeds 288
# iteration proceeds 289
# iteration proceeds 290
# iteration proceeds 291
# iteration proceeds 292
# iteration proceeds 293
# iteration proceeds 294
# iteration proceeds 295
# iteration proceeds 296
# iteration proceeds 297
# iteration proceeds 298
# iteration proceeds 299
# iteration proceeds 300
# iteration proceeds 301
# iteration proceeds 302
# iteration proceeds 303
# iteration proceeds 304
# iteration proceeds 305
# iteration proceeds 306
# iteration proceeds 307
# iteration proceeds 308
# iteration proceeds 309
# iteration proceeds 310
# iteration proceeds 311
# iteration proceeds 312
# iteration proceeds 313
# iteration proceeds 314
# iteration proceeds 315
# iteration proceeds 316
# iteration proceeds 317
# iteration proceeds 318
# iteration proceeds 319
# iteration proceeds 320
# iteration proceeds 321
# iteration proceeds 322
# iteration proceeds 323
# iteration proceeds 324
# iteration proceeds 325
# iteration proceeds 326
# iteration proceeds 327
# iteration proceeds 328
# iteration proceeds 329
# iteration proceeds 330
# iteration proceeds 331
# iteration proceeds 332
# iteration proceeds 333
# iteration proceeds 334
# iteration proceeds 335
# iteration proceeds 336
# iteration proceeds 337
# iteration proceeds 338
# iteration proceeds 339
# iteration proceeds 340
# iteration proceeds 341
# iteration proceeds 342
# iteration proceeds 343
# iteration proceeds 344
# iteration proceeds 345
# iteration proceeds 346
# iteration proceeds 347
# iteration proceeds 348
# iteration proceeds 349
# iteration proceeds 350
# iteration proceeds 351
# iteration proceeds 352
# iteration proceeds 353
# iteration proceeds 354
# iteration proceeds 355
# iteration proceeds 356
# iteration proceeds 357
# iteration proceeds 358
# iteration proceeds 359
# iteration proceeds 360
# iteration proceeds 361
# iteration proceeds 362
# iteration proceeds 363
# iteration proceeds 364
# iteration proceeds 365
# iteration proceeds 366
# iteration proceeds 367
# iteration proceeds 368
# iteration proceeds 369
# iteration proceeds 370
# iteration proceeds 371
# iteration proceeds 372
# iteration proceeds 373
# iteration proceeds 374
# iteration proceeds 375
# iteration proceeds 376
# iteration proceeds 377
# iteration proceeds 378
# iteration proceeds 379
# iteration proceeds 380
# iteration proceeds 381
# iteration proceeds 382
# iteration proceeds 383
# iteration proceeds 384
# iteration proceeds 385
# iteration proceeds 386
# iteration proceeds 387
# iteration proceeds 388
# iteration proceeds 389
# iteration proceeds 390
# iteration proceeds 391
# iteration proceeds 392
# iteration proceeds 393
# iteration proceeds 394
# iteration proceeds 395
# iteration proceeds 396
# iteration proceeds 397
# iteration proceeds 398
# iteration proceeds 399
# iteration proceeds 400
# iteration proceeds 401
# iteration proceeds 402
# iteration proceeds 403
# iteration proceeds 404
# iteration proceeds 405
# iteration proceeds 406
# iteration proceeds 407
# iteration proceeds 408
# iteration proceeds 409
# iteration proceeds 410
# iteration proceeds 411
# iteration proceeds 412
# iteration proceeds 413
# iteration proceeds 414
# iteration proceeds 415
# iteration proceeds 416
# iteration proceeds 417
# iteration proceeds 418
# iteration proceeds 419
# iteration proceeds 420
# iteration proceeds 421
# iteration proceeds 422
# iteration proceeds 423
# iteration proceeds 424
# iteration proceeds 425
# iteration proceeds 426
# iteration proceeds 427
# iteration proceeds 428
# iteration proceeds 429
# iteration proceeds 430
# iteration proceeds 431
# iteration proceeds 432
# iteration proceeds 433
# iteration proceeds 434
# iteration proceeds 435
# iteration proceeds 436
# iteration proceeds 437
# iteration proceeds 438
# iteration proceeds 439
# iteration proceeds 440
# iteration proceeds 441
# iteration proceeds 442
# iteration proceeds 443
# iteration proceeds 444
# iteration proceeds 445
# iteration proceeds 446
# iteration proceeds 447
# iteration proceeds 448
# iteration proceeds 449
# iteration proceeds 450
# iteration proceeds 451
# iteration proceeds 452
# iteration proceeds 453
# iteration proceeds 454
# iteration proceeds 455
# iteration proceeds 456
# iteration proceeds 457
# iteration proceeds 458
# iteration proceeds 459
# iteration proceeds 460
# iteration proceeds 461
# iteration proceeds 462
# iteration proceeds 463
# iteration proceeds 464
# iteration proceeds 465
# iteration proceeds 466
# iteration proceeds 467
# iteration proceeds 468
# iteration proceeds 469
# iteration proceeds 470
# iteration proceeds 471
# iteration proceeds 472
# iteration proceeds 473
# iteration proceeds 474
# iteration proceeds 475
# iteration proceeds 476
# iteration proceeds 477
# iteration proceeds 478
# iteration proceeds 479
# iteration proceeds 480
# iteration proceeds 481
# iteration proceeds 482
# iteration proceeds 483
# iteration proceeds 484
# iteration proceeds 485
# iteration proceeds 486
# iteration proceeds 487
# iteration proceeds 488
# iteration proceeds 489
# iteration proceeds 490
# iteration proceeds 491
# iteration proceeds 492
# iteration proceeds 493
# iteration proceeds 494
# iteration proceeds 495
# iteration proceeds 496
# iteration proceeds 497
# iteration proceeds 498
# iteration proceeds 499
# gradient descent mean via torch 2.0202038288116455
# gradient descent std via torch 3.994776487350464
# ground truth mean via maximum likelihood 2.02020308037172
# ground truth std via maximum likelihood 3.994776297943574

# %% [markdown]
# If coding correctly, you will be able to see the model parameters `mean` and `std` computed via pytorch above are very close to the ground truth values computed from their analytical solutions. However, here gradients were computed automatically thanks to *Automatic Differentiation*
